# %% [markdown]
# # QF603 Project - Alpha Generation, Portfolio Construction

# %% [markdown]
# ## by Team Alpha : DENG Ke, LEE How-Chih Howard, LEI YuMing, SOH Giap Hong Daniel , WANG WenJie, XUE Yuanhuang, YU ChunXue

# %% [markdown]
# # Slide1 (15s)
# Slide:(screenshot code below) to show which industry we define covid positive which we define covid negative as a overview
#
# Talking:When covid comes will have positive or negative effect on stock price, 1 means positive effect while 0 means negative effect.

# %%
industry_mapping = ({'Banks': 0,
                     'Real Estate': 0,
                     'Communication Equipment & Technical Services': 0,
                     "Capital Markets": 0,
                     "Household Durables": 1,
                     "Food, Beverage & Tobacco": 0,
                     "Electronics": 0,
                     "Retailing": 0,
                     "Media": 1,
                     "Pharmaceuticals": 1,
                     'Transportation': 0,
                     'Passenger Vehicles & Auto Parts': 0,
                     'Consumer Services': 0,
                     'Agriculture, Animal Husbandry & Fishery': 0,
                     'Electrical Equipment': 1,
                     'Medical Treatment': 1,
                     'Steel': 0,
                     'Utilities': 1,
                     'Energy': 0,
                     'Machinery': 0,
                     'Telecom Services': 1,
                     'Chemicals': 0,
                     'Non-metal Mining & Products': 0,
                     'Construction & Decoration': 0,
                     'Insurance': 1,
                     'Computers': 0,
                     'Non-ferrous Metals': 0,
                     'Semiconductors': 0
                     }
)

# %% [markdown]
# # Slide2(30s)
# Slide:write down below cell using easy to look format
#
# Talking:Intutively, covid will have negative effect on most industries, so here we list short reason why our team think it's covid positive.
# And I will cover pharmaceutical and telecom services as examples

# %% [markdown]
# 1."Household Durables":For "Household Durables",lockdowns and stay-at-home orders led to an increased demand for household items and durables as people spent more time at home.
#
# 2."Media":The media industry experienced higher viewership and readership as people spent more time at home, leading to increased advertising and subscription revenue.
#
# 3."Pharmaceuticals":The pandemic accelerated research and development in the pharmaceutical sector, leading to the rapid creation of multiple COVID-19 vaccines.
#
# 4.'Electrical Equipment':Increased demand for remote work and online learning led to higher sales of electrical equipment, such as computers, monitors, and peripherals.
#
# 5.'Medical Treatment':The adoption of telehealth services surged, allowing patients to access medical treatment remotely, ensuring continuity of care and contributing to the growth of telemedicine platforms.
#
# 6.'Utilities':Utilities like electricity and water remained essential services, with steady demand during the pandemic, providing revenue stability even during economic uncertainty.
#
# 7.'Telecom Services':The need for remote work, online education, and entertainment drove up demand for telecom services, particularly high-speed internet and mobile data.
#
# 8.'Insurance':The insurance industry accelerated its digital transformation efforts, allowing for remote customer interactions, claims processing, and the creation of innovative policies, contributing to improved customer service and cost-efficiency.

# %% [markdown]
# # Slide3(20s)
# Slide:screenshot the result without code and need to have red circle on "Chongqing Zhifei Biological Products Co Ltd" and "Jiangsu Hengrui Medicine Co Ltd"
#
# Talking:Here is our covid positive companies. I think our work is worthy, at least we don't have Maotai Liquor and Wuliangye Liquor as our covid positive and more importantly we got "Hengrui" and "Zhifei".Both them provide covid vaccine and mask, and of course their stock price skyracket!

# %%
df_covid = pd.DataFrame()
df_covid[['security_code','securityNameEn', 'covid_positive']] = security_info1[['security_code','securityNameEn','covid_positive']]
df_covid_test = df_covid[(df_covid['covid_positive']>0)]
df_covid_test
# Out:
#     security_code                                     securityNameEn  \
# 4       000333.SZ                               Midea Group CO., LTD
# 6       000651.SZ            Gree Electric Appliances,Inc. of Zhuhai
# 12      002027.SZ       Focus Media Information Technology Co., Ltd.
# 14      002252.SZ                Shanghai RAAS Blood Products Co Ltd
# 23      300014.SZ                                  Eve Energy Co Ltd
# 24      300015.SZ                     Aier Eye Hospital Group Co Ltd
# 26      300122.SZ        Chongqing Zhifei Biological Products Co Ltd
# 28      300750.SZ      Contemporary Amperex Technology Co., Limited.
# 29      300760.SZ  Shenzhen Mindray Bio-Medical Electronics Co., ...
# 34      600011.SS                    Huaneng Power International Inc
# 38      600023.SS          Zhejiang Zheneng Electric Power Co., Ltd.
# 44      600050.SS         China United Network Communications Co Ltd
# 46      600276.SS                    Jiangsu Hengrui Medicine Co Ltd
# ...

# %% [markdown]
# # Slide4(30s)
# Slide: put below image into one slide oppositely
#
# Talking:so during covid period we have a huge argument about we should chage our strategy or not for covid as a huge factor, and our another researcher Daniel will talk about it later. Anyway as our team all quants, so we only use data to talk, we stick our strategy, and backtest to see if we're right, and luckly we're at least not wrong.
#
# as you can see, covid positve not outperform our strategy, and they are outperform than index which is also a good news. And here welcome Daniel to continue.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
